# %% [markdown]
# <a href="https://colab.research.google.com/github/imankit23/Comparative-analysis-between-Neuro-symbolic-and-Deep-Learning-IDS/blob/main/cnn_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **For Data Preprocessing task**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten
from keras.optimizers import SGD
import os
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv("/content/friday.csv") #CSE-CIC-IDS 2017 (friday )
df
# Out:
#             id                                  Flow ID         Src IP  \
# 0            1  192.168.10.50-192.168.10.3-56108-3268-6  192.168.10.50
# 1            2   192.168.10.50-192.168.10.3-42144-389-6  192.168.10.50
# 2            3                    8.6.0.1-8.0.6.4-0-0-0        8.6.0.1
# 3            4   192.168.10.25-224.0.0.251-5353-5353-17  192.168.10.25
# 4            5   192.168.10.25-17.253.14.125-123-123-17  192.168.10.25
# ...        ...                                      ...            ...
# 547552  547553    172.16.0.1-192.168.10.50-64318-2222-6     172.16.0.1
# 547553  547554    172.16.0.1-192.168.10.50-33248-9040-6     172.16.0.1
# 547554  547555    172.16.0.1-192.168.10.50-44033-1272-6     172.16.0.1
# 547555  547556   192.168.10.16-192.168.10.3-64748-53-17  192.168.10.16
# 547556  547557  192.168.10.51-162.213.33.50-58853-443-6  192.168.10.51
#
#         Src Port         Dst IP  Dst Port  Protocol  \
# 0          56108   192.168.10.3      3268         6
# 1          42144   192.168.10.3       389         6
# 2              0        8.0.6.4         0         0
# 3           5353    224.0.0.251      5353        17
# 4            123  17.253.14.125       123        17
# ...          ...            ...       ...       ...
# 547552     64318  192.168.10.50      2222         6
# 547553     33248  192.168.10.50      9040         6
# 547554     44033  192.168.10.50      1272         6
# 547555     64748   192.168.10.3        53        17
# 547556     58853  162.213.33.50       443         6
#
#                          Timestamp  Flow Duration  Total Fwd Packet  ...  \
# 0       2017-07-07 11:59:50.315195      112740690                32  ...
# 1       2017-07-07 11:59:50.316273      112740560                32  ...
# 2       2017-07-07 12:00:31.388567      113757377               545  ...
# 3       2017-07-07 12:00:42.903850       91997219               388  ...
# 4       2017-07-07 12:00:42.430758       66966070                 6  ...
# ...                            ...            ...               ...  ...
# 547552  2017-07-07 18:09:11.499555             64                 1  ...
# 547553  2017-07-07 17:54:38.857717             76                 1  ...
# 547554  2017-07-07 17:52:03.285040             81                 1  ...
# 547555  2017-07-07 18:33:45.701233            297                 2  ...
# 547556  2017-07-07 13:46:39.176784        3295131                13  ...
#
#         Active Min     Idle Mean      Idle Std  Idle Max  Idle Min  ICMP Code  \
# 0              343  1.610540e+07  4.988048e+05  16399772  15375229         -1
# 1              285  1.610543e+07  4.987937e+05  16399782  15375263         -1
# 2               19  1.221036e+07  6.935824e+06  20757030   5504997         -1
# 3               16  1.319764e+07  5.826905e+06  19776791   5817470         -1
# 4          1968172  6.497443e+07  0.000000e+00  64974431  64974431         -1
# ...            ...           ...           ...       ...       ...        ...
# 547552           0  0.000000e+00  0.000000e+00         0         0         -1
# 547553           0  0.000000e+00  0.000000e+00         0         0         -1
# 547554           0  0.000000e+00  0.000000e+00         0         0         -1
# 547555           0  0.000000e+00  0.000000e+00         0         0         -1
# 547556           0  0.000000e+00  0.000000e+00         0         0         -1
#
#         ICMP Type  Total TCP Flow Time     Label  Attempted Category
# 0              -1            112740690    BENIGN                  -1
# 1              -1            112740560    BENIGN                  -1
# 2              -1                    0    BENIGN                  -1
# 3              -1                    0    BENIGN                  -1
# 4              -1                    0    BENIGN                  -1
# ...           ...                  ...       ...                 ...
# 547552         -1                   64  Portscan                  -1
# 547553         -1                   76  Portscan                  -1
# 547554         -1                   81  Portscan                  -1
# 547555         -1                    0    BENIGN                  -1
# 547556         -1              3295131    BENIGN                  -1
#
# [547557 rows x 91 columns]

# %%
print(df.head())
print(df['Label'].value_counts())
# Out:
#    id                                  Flow ID         Src IP  Src Port  \
# 0   1  192.168.10.50-192.168.10.3-56108-3268-6  192.168.10.50     56108
# 1   2   192.168.10.50-192.168.10.3-42144-389-6  192.168.10.50     42144
# 2   3                    8.6.0.1-8.0.6.4-0-0-0        8.6.0.1         0
# 3   4   192.168.10.25-224.0.0.251-5353-5353-17  192.168.10.25      5353
# 4   5   192.168.10.25-17.253.14.125-123-123-17  192.168.10.25       123
#
#           Dst IP  Dst Port  Protocol                   Timestamp  \
# 0   192.168.10.3      3268         6  2017-07-07 11:59:50.315195
# 1   192.168.10.3       389         6  2017-07-07 11:59:50.316273
# 2        8.0.6.4         0         0  2017-07-07 12:00:31.388567
# 3    224.0.0.251      5353        17  2017-07-07 12:00:42.903850
# 4  17.253.14.125       123        17  2017-07-07 12:00:42.430758
#
#    Flow Duration  Total Fwd Packet  ...  Active Min     Idle Mean  \
# 0      112740690                32  ...         343  1.610540e+07
# 1      112740560                32  ...         285  1.610543e+07
# 2      113757377               545  ...          19  1.221036e+07
# 3       91997219               388  ...          16  1.319764e+07
# 4       66966070                 6  ...     1968172  6.497443e+07
#
#        Idle Std  Idle Max  Idle Min  ICMP Code  ICMP Type  \
# 0  4.988048e+05  16399772  15375229         -1         -1
# 1  4.987937e+05  16399782  15375263         -1         -1
# 2  6.935824e+06  20757030   5504997         -1         -1
# 3  5.826905e+06  19776791   5817470         -1         -1
# 4  0.000000e+00  64974431  64974431         -1         -1
#
#    Total TCP Flow Time   Label  Attempted Category
# 0            112740690  BENIGN                  -1
# 1            112740560  BENIGN                  -1
# 2                    0  BENIGN                  -1
# 3                    0  BENIGN                  -1
# 4                    0  BENIGN                  -1
#
# [5 rows x 91 columns]
# Label
# BENIGN                288544
# Portscan              159066
# DDoS                   95144
# Botnet - Attempted      4067
# Botnet                   736
# Name: count, dtype: int64

# %%
cols = df.columns
cols = cols.map(lambda x: x.replace(' ', '_') )
df.columns = cols
print(df.head())
# Out:
#    id                                  Flow_ID         Src_IP  Src_Port  \
# 0   1  192.168.10.50-192.168.10.3-56108-3268-6  192.168.10.50     56108
# 1   2   192.168.10.50-192.168.10.3-42144-389-6  192.168.10.50     42144
# 2   3                    8.6.0.1-8.0.6.4-0-0-0        8.6.0.1         0
# 3   4   192.168.10.25-224.0.0.251-5353-5353-17  192.168.10.25      5353
# 4   5   192.168.10.25-17.253.14.125-123-123-17  192.168.10.25       123
#
#           Dst_IP  Dst_Port  Protocol                   Timestamp  \
# 0   192.168.10.3      3268         6  2017-07-07 11:59:50.315195
# 1   192.168.10.3       389         6  2017-07-07 11:59:50.316273
# 2        8.0.6.4         0         0  2017-07-07 12:00:31.388567
# 3    224.0.0.251      5353        17  2017-07-07 12:00:42.903850
# 4  17.253.14.125       123        17  2017-07-07 12:00:42.430758
#
#    Flow_Duration  Total_Fwd_Packet  ...  Active_Min     Idle_Mean  \
# 0      112740690                32  ...         343  1.610540e+07
# 1      112740560                32  ...         285  1.610543e+07
# 2      113757377               545  ...          19  1.221036e+07
# 3       91997219               388  ...          16  1.319764e+07
# 4       66966070                 6  ...     1968172  6.497443e+07
#
#        Idle_Std  Idle_Max  Idle_Min  ICMP_Code  ICMP_Type  \
# 0  4.988048e+05  16399772  15375229         -1         -1
# 1  4.987937e+05  16399782  15375263         -1         -1
# 2  6.935824e+06  20757030   5504997         -1         -1
# 3  5.826905e+06  19776791   5817470         -1         -1
# 4  0.000000e+00  64974431  64974431         -1         -1
#
#    Total_TCP_Flow_Time   Label  Attempted_Category
# 0            112740690  BENIGN                  -1
# 1            112740560  BENIGN                  -1
# 2                    0  BENIGN                  -1
# 3                    0  BENIGN                  -1
# 4                    0  BENIGN                  -1
#
# [5 rows x 91 columns]

# %%
#replace infinit number
df=df.replace([np.inf, -np.inf], np.nan).dropna(axis=1)

#drop null
df.dropna(how = 'all')
# Out:
#             id                                  Flow_ID         Src_IP  \
# 0            1  192.168.10.50-192.168.10.3-56108-3268-6  192.168.10.50
# 1            2   192.168.10.50-192.168.10.3-42144-389-6  192.168.10.50
# 2            3                    8.6.0.1-8.0.6.4-0-0-0        8.6.0.1
# 3            4   192.168.10.25-224.0.0.251-5353-5353-17  192.168.10.25
# 4            5   192.168.10.25-17.253.14.125-123-123-17  192.168.10.25
# ...        ...                                      ...            ...
# 547552  547553    172.16.0.1-192.168.10.50-64318-2222-6     172.16.0.1
# 547553  547554    172.16.0.1-192.168.10.50-33248-9040-6     172.16.0.1
# 547554  547555    172.16.0.1-192.168.10.50-44033-1272-6     172.16.0.1
# 547555  547556   192.168.10.16-192.168.10.3-64748-53-17  192.168.10.16
# 547556  547557  192.168.10.51-162.213.33.50-58853-443-6  192.168.10.51
#
#         Src_Port         Dst_IP  Dst_Port  Protocol  \
# 0          56108   192.168.10.3      3268         6
# 1          42144   192.168.10.3       389         6
# 2              0        8.0.6.4         0         0
# 3           5353    224.0.0.251      5353        17
# 4            123  17.253.14.125       123        17
# ...          ...            ...       ...       ...
# 547552     64318  192.168.10.50      2222         6
# 547553     33248  192.168.10.50      9040         6
# 547554     44033  192.168.10.50      1272         6
# 547555     64748   192.168.10.3        53        17
# 547556     58853  162.213.33.50       443         6
#
#                          Timestamp  Flow_Duration  Total_Fwd_Packet  ...  \
# 0       2017-07-07 11:59:50.315195      112740690                32  ...
# 1       2017-07-07 11:59:50.316273      112740560                32  ...
# 2       2017-07-07 12:00:31.388567      113757377               545  ...
# 3       2017-07-07 12:00:42.903850       91997219               388  ...
# 4       2017-07-07 12:00:42.430758       66966070                 6  ...
# ...                            ...            ...               ...  ...
# 547552  2017-07-07 18:09:11.499555             64                 1  ...
# 547553  2017-07-07 17:54:38.857717             76                 1  ...
# 547554  2017-07-07 17:52:03.285040             81                 1  ...
# 547555  2017-07-07 18:33:45.701233            297                 2  ...
# 547556  2017-07-07 13:46:39.176784        3295131                13  ...
#
#         Active_Min     Idle_Mean      Idle_Std  Idle_Max  Idle_Min  ICMP_Code  \
# 0              343  1.610540e+07  4.988048e+05  16399772  15375229         -1
# 1              285  1.610543e+07  4.987937e+05  16399782  15375263         -1
# 2               19  1.221036e+07  6.935824e+06  20757030   5504997         -1
# 3               16  1.319764e+07  5.826905e+06  19776791   5817470         -1
# 4          1968172  6.497443e+07  0.000000e+00  64974431  64974431         -1
# ...            ...           ...           ...       ...       ...        ...
# 547552           0  0.000000e+00  0.000000e+00         0         0         -1
# 547553           0  0.000000e+00  0.000000e+00         0         0         -1
# 547554           0  0.000000e+00  0.000000e+00         0         0         -1
# 547555           0  0.000000e+00  0.000000e+00         0         0         -1
# 547556           0  0.000000e+00  0.000000e+00         0         0         -1
#
#         ICMP_Type  Total_TCP_Flow_Time     Label  Attempted_Category
# 0              -1            112740690    BENIGN                  -1
# 1              -1            112740560    BENIGN                  -1
# 2              -1                    0    BENIGN                  -1
# 3              -1                    0    BENIGN                  -1
# 4              -1                    0    BENIGN                  -1
# ...           ...                  ...       ...                 ...
# 547552         -1                   64  Portscan                  -1
# 547553         -1                   76  Portscan                  -1
# 547554         -1                   81  Portscan                  -1
# 547555         -1                    0    BENIGN                  -1
# 547556         -1              3295131    BENIGN                  -1
#
# [547557 rows x 91 columns]

# %%
print('Data type of each column of Dataframe :')
df.info(verbose=True)
# Out:
# Data type of each column of Dataframe :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547557 entries, 0 to 547556
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          547557 non-null  int64
#  1   Flow_ID                     547557 non-null  object
#  2   Src_IP                      547557 non-null  object
#  3   Src_Port                    547557 non-null  int64
#  4   Dst_IP                      547557 non-null  object
#  5   Dst_Port                    547557 non-null  int64
#  6   Protocol                    547557 non-null  int64
#  7   Timestamp                   547557 non-null  object
#  8   Flow_Duration               547557 non-null  int64
#  9   Total_Fwd_Packet            547557 non-null  int64
#  10  Total_Bwd_packets           547557 non-null  int64
#  11  Total_Length_of_Fwd_Packet  547557 non-null  int64
#  12  Total_Length_of_Bwd_Packet  547557 non-null  int64
#  13  Fwd_Packet_Length_Max       547557 non-null  int64
#  14  Fwd_Packet_Length_Min       547557 non-null  int64
#  15  Fwd_Packet_Length_Mean      547557 non-null  float64
#  16  Fwd_Packet_Length_Std       547557 non-null  float64
#  17  Bwd_Packet_Length_Max       547557 non-null  int64
#  18  Bwd_Packet_Length_Min       547557 non-null  int64
#  19  Bwd_Packet_Length_Mean      547557 non-null  float64
#  20  Bwd_Packet_Length_Std       547557 non-null  float64
#  21  Flow_Bytes/s                547557 non-null  float64
#  22  Flow_Packets/s              547557 non-null  float64
#  23  Flow_IAT_Mean               547557 non-null  float64
#  24  Flow_IAT_Std                547557 non-null  float64
#  25  Flow_IAT_Max                547557 non-null  int64
#  26  Flow_IAT_Min                547557 non-null  int64
#  27  Fwd_IAT_Total               547557 non-null  int64
#  28  Fwd_IAT_Mean                547557 non-null  float64
#  29  Fwd_IAT_Std                 547557 non-null  float64
#  30  Fwd_IAT_Max                 547557 non-null  int64
#  31  Fwd_IAT_Min                 547557 non-null  int64
#  32  Bwd_IAT_Total               547557 non-null  int64
#  33  Bwd_IAT_Mean                547557 non-null  float64
#  34  Bwd_IAT_Std                 547557 non-null  float64
#  35  Bwd_IAT_Max                 547557 non-null  int64
#  36  Bwd_IAT_Min                 547557 non-null  int64
#  37  Fwd_PSH_Flags               547557 non-null  int64
#  38  Bwd_PSH_Flags               547557 non-null  int64
#  39  Fwd_URG_Flags               547557 non-null  int64
#  40  Bwd_URG_Flags               547557 non-null  int64
#  41  Fwd_RST_Flags               547557 non-null  int64
#  42  Bwd_RST_Flags               547557 non-null  int64
#  43  Fwd_Header_Length           547557 non-null  int64
#  44  Bwd_Header_Length           547557 non-null  int64
#  45  Fwd_Packets/s               547557 non-null  float64
#  46  Bwd_Packets/s               547557 non-null  float64
#  47  Packet_Length_Min           547557 non-null  int64
#  48  Packet_Length_Max           547557 non-null  int64
#  49  Packet_Length_Mean          547557 non-null  float64
#  50  Packet_Length_Std           547557 non-null  float64
#  51  Packet_Length_Variance      547557 non-null  float64
#  52  FIN_Flag_Count              547557 non-null  int64
#  53  SYN_Flag_Count              547557 non-null  int64
#  54  RST_Flag_Count              547557 non-null  int64
#  55  PSH_Flag_Count              547557 non-null  int64
#  56  ACK_Flag_Count              547557 non-null  int64
#  57  URG_Flag_Count              547557 non-null  int64
#  58  CWR_Flag_Count              547557 non-null  int64
#  59  ECE_Flag_Count              547557 non-null  int64
#  60  Down/Up_Ratio               547557 non-null  float64
#  61  Average_Packet_Size         547557 non-null  float64
#  62  Fwd_Segment_Size_Avg        547557 non-null  float64
#  63  Bwd_Segment_Size_Avg        547557 non-null  float64
#  64  Fwd_Bytes/Bulk_Avg          547557 non-null  int64
#  65  Fwd_Packet/Bulk_Avg         547557 non-null  int64
#  66  Fwd_Bulk_Rate_Avg           547557 non-null  int64
#  67  Bwd_Bytes/Bulk_Avg          547557 non-null  int64
#  68  Bwd_Packet/Bulk_Avg         547557 non-null  int64
#  69  Bwd_Bulk_Rate_Avg           547557 non-null  int64
#  70  Subflow_Fwd_Packets         547557 non-null  int64
#  71  Subflow_Fwd_Bytes           547557 non-null  int64
#  72  Subflow_Bwd_Packets         547557 non-null  int64
#  73  Subflow_Bwd_Bytes           547557 non-null  int64
#  74  FWD_Init_Win_Bytes          547557 non-null  int64
#  75  Bwd_Init_Win_Bytes          547557 non-null  int64
#  76  Fwd_Act_Data_Pkts           547557 non-null  int64
#  77  Fwd_Seg_Size_Min            547557 non-null  int64
#  78  Active_Mean                 547557 non-null  float64
#  79  Active_Std                  547557 non-null  float64
#  80  Active_Max                  547557 non-null  int64
#  81  Active_Min                  547557 non-null  int64
#  82  Idle_Mean                   547557 non-null  float64
#  83  Idle_Std                    547557 non-null  float64
#  84  Idle_Max                    547557 non-null  int64
#  85  Idle_Min                    547557 non-null  int64
#  86  ICMP_Code                   547557 non-null  int64
#  87  ICMP_Type                   547557 non-null  int64
#  88  Total_TCP_Flow_Time         547557 non-null  int64
#  89  Label                       547557 non-null  object
#  90  Attempted_Category          547557 non-null  int64
# dtypes: float64(25), int64(61), object(5)
# memory usage: 380.2+ MB

# %%
df = df.drop(columns=['Timestamp', 'Flow_ID', 'Src_IP', 'Dst_IP'])
print('Timestamp, ', 'Flow_ID, ', 'Src_IP, ', 'Dst_IP, ', "columns are dropped")
# Out:
# Timestamp,  Flow_ID,  Src_IP,  Dst_IP,  columns are dropped

# %%
print(df['Label'].value_counts())
# Out:
# Label
# BENIGN                288544
# Portscan              159066
# DDoS                   95144
# Botnet - Attempted      4067
# Botnet                   736
# Name: count, dtype: int64

# %%
df.Label[df.Label=='BENIGN'] = 0
df.Label[df.Label =='Portscan'] = 1
df.Label[df.Label =='DDoS'] = 1
df.Label[df.Label =='Botnet - Attempted'] = 1
df.Label[df.Label =='Botnet'] = 1
df["Label"].astype('Int64')
print(df['Label'].value_counts())
# Out:
# /tmp/ipython-input-3053153228.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.Label[df.Label=='BENIGN'] = 0
# /tmp/ipython-input-3053153228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Label[df.Label=='BENIGN'] = 0
# /tmp/ipython-input-3053153228.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.Label[df.Label =='Portscan'] = 1
# /tmp/ipython-input-3053153228.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Label[df.Label =='Portscan'] = 1
# /tmp/ipython-input-3053153228.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.Label[df.Label =='DDoS'] = 1
# /tmp/ipython-input-3053153228.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Label[df.Label =='DDoS'] = 1
# /tmp/ipython-input-3053153228.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.Label[df.Label =='Botnet - Attempted'] = 1
# /tmp/ipython-input-3053153228.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Label[df.Label =='Botnet - Attempted'] = 1
# Label
# 0    288544
# 1    259013
# Name: count, dtype: int64
# /tmp/ipython-input-3053153228.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.Label[df.Label =='Botnet'] = 1
# /tmp/ipython-input-3053153228.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Label[df.Label =='Botnet'] = 1

# %%
# Count the number of rows in each class
ddos_count = df[df['Label'] == 1].shape[0]
benign_count = df[df['Label'] == 0].shape[0]

# Randomly sample the benign rows to reduce their count
df_benign = df[df['Label'] == 0].sample(n=ddos_count, random_state=42)

# Combine the DDoS and sampled benign rows into a new dataframe
df_reduced = pd.concat([df[df['Label'] == 1], df_benign])

# Shuffle the rows in the new dataframe
df_reduced = df_reduced.sample(frac=1, random_state=42)

df = df_reduced
df["Label"].astype('float')
print(df['Label'].value_counts())
# Out:
# Label
# 0    259013
# 1    259013
# Name: count, dtype: int64

# %%
bening_df = df[df['Label']==0]
malignant_df = df[df['Label']==1]

# %%
axes = bening_df.plot(kind='scatter', x='Flow_Duration', y = 'Total_Fwd_Packet', color='blue', label='Benign')
malignant_df.plot(kind='scatter', x='Flow_Duration', y = 'Total_Fwd_Packet', color='red', label='maligmant', ax=axes)
# Out:
# <Axes: xlabel='Flow_Duration', ylabel='Total_Fwd_Packet'>

# %%
cat_cols = df.select_dtypes(include=['object', 'category']).columns
print(cat_cols)

cat_cols = df.select_dtypes(include='object').columns
print(cat_cols)

print('Data type of each column of Dataframe :')
df.info(verbose=True)
# Out:
# Index(['Label'], dtype='object')
# Index(['Label'], dtype='object')
# Data type of each column of Dataframe :
# <class 'pandas.core.frame.DataFrame'>
# Index: 518026 entries, 2904 to 284187
# Data columns (total 87 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          518026 non-null  int64
#  1   Src_Port                    518026 non-null  int64
#  2   Dst_Port                    518026 non-null  int64
#  3   Protocol                    518026 non-null  int64
#  4   Flow_Duration               518026 non-null  int64
#  5   Total_Fwd_Packet            518026 non-null  int64
#  6   Total_Bwd_packets           518026 non-null  int64
#  7   Total_Length_of_Fwd_Packet  518026 non-null  int64
#  8   Total_Length_of_Bwd_Packet  518026 non-null  int64
#  9   Fwd_Packet_Length_Max       518026 non-null  int64
#  10  Fwd_Packet_Length_Min       518026 non-null  int64
#  11  Fwd_Packet_Length_Mean      518026 non-null  float64
#  12  Fwd_Packet_Length_Std       518026 non-null  float64
#  13  Bwd_Packet_Length_Max       518026 non-null  int64
#  14  Bwd_Packet_Length_Min       518026 non-null  int64
#  15  Bwd_Packet_Length_Mean      518026 non-null  float64
#  16  Bwd_Packet_Length_Std       518026 non-null  float64
#  17  Flow_Bytes/s                518026 non-null  float64
#  18  Flow_Packets/s              518026 non-null  float64
#  19  Flow_IAT_Mean               518026 non-null  float64
#  20  Flow_IAT_Std                518026 non-null  float64
#  21  Flow_IAT_Max                518026 non-null  int64
#  22  Flow_IAT_Min                518026 non-null  int64
#  23  Fwd_IAT_Total               518026 non-null  int64
#  24  Fwd_IAT_Mean                518026 non-null  float64
#  25  Fwd_IAT_Std                 518026 non-null  float64
#  26  Fwd_IAT_Max                 518026 non-null  int64
#  27  Fwd_IAT_Min                 518026 non-null  int64
#  28  Bwd_IAT_Total               518026 non-null  int64
#  29  Bwd_IAT_Mean                518026 non-null  float64
#  30  Bwd_IAT_Std                 518026 non-null  float64
#  31  Bwd_IAT_Max                 518026 non-null  int64
#  32  Bwd_IAT_Min                 518026 non-null  int64
#  33  Fwd_PSH_Flags               518026 non-null  int64
#  34  Bwd_PSH_Flags               518026 non-null  int64
#  35  Fwd_URG_Flags               518026 non-null  int64
#  36  Bwd_URG_Flags               518026 non-null  int64
#  37  Fwd_RST_Flags               518026 non-null  int64
#  38  Bwd_RST_Flags               518026 non-null  int64
#  39  Fwd_Header_Length           518026 non-null  int64
#  40  Bwd_Header_Length           518026 non-null  int64
#  41  Fwd_Packets/s               518026 non-null  float64
#  42  Bwd_Packets/s               518026 non-null  float64
#  43  Packet_Length_Min           518026 non-null  int64
#  44  Packet_Length_Max           518026 non-null  int64
#  45  Packet_Length_Mean          518026 non-null  float64
#  46  Packet_Length_Std           518026 non-null  float64
#  47  Packet_Length_Variance      518026 non-null  float64
#  48  FIN_Flag_Count              518026 non-null  int64
#  49  SYN_Flag_Count              518026 non-null  int64
#  50  RST_Flag_Count              518026 non-null  int64
#  51  PSH_Flag_Count              518026 non-null  int64
#  52  ACK_Flag_Count              518026 non-null  int64
#  53  URG_Flag_Count              518026 non-null  int64
#  54  CWR_Flag_Count              518026 non-null  int64
#  55  ECE_Flag_Count              518026 non-null  int64
#  56  Down/Up_Ratio               518026 non-null  float64
#  57  Average_Packet_Size         518026 non-null  float64
#  58  Fwd_Segment_Size_Avg        518026 non-null  float64
#  59  Bwd_Segment_Size_Avg        518026 non-null  float64
#  60  Fwd_Bytes/Bulk_Avg          518026 non-null  int64
#  61  Fwd_Packet/Bulk_Avg         518026 non-null  int64
#  62  Fwd_Bulk_Rate_Avg           518026 non-null  int64
#  63  Bwd_Bytes/Bulk_Avg          518026 non-null  int64
#  64  Bwd_Packet/Bulk_Avg         518026 non-null  int64
#  65  Bwd_Bulk_Rate_Avg           518026 non-null  int64
#  66  Subflow_Fwd_Packets         518026 non-null  int64
#  67  Subflow_Fwd_Bytes           518026 non-null  int64
#  68  Subflow_Bwd_Packets         518026 non-null  int64
#  69  Subflow_Bwd_Bytes           518026 non-null  int64
#  70  FWD_Init_Win_Bytes          518026 non-null  int64
#  71  Bwd_Init_Win_Bytes          518026 non-null  int64
#  72  Fwd_Act_Data_Pkts           518026 non-null  int64
#  73  Fwd_Seg_Size_Min            518026 non-null  int64
#  74  Active_Mean                 518026 non-null  float64
#  75  Active_Std                  518026 non-null  float64
#  76  Active_Max                  518026 non-null  int64
#  77  Active_Min                  518026 non-null  int64
#  78  Idle_Mean                   518026 non-null  float64
#  79  Idle_Std                    518026 non-null  float64
#  80  Idle_Max                    518026 non-null  int64
#  81  Idle_Min                    518026 non-null  int64
#  82  ICMP_Code                   518026 non-null  int64
#  83  ICMP_Type                   518026 non-null  int64
#  84  Total_TCP_Flow_Time         518026 non-null  int64
#  85  Label                       518026 non-null  object
#  86  Attempted_Category          518026 non-null  int64
# dtypes: float64(25), int64(61), object(1)
# memory usage: 347.8+ MB

# %%
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# Select a subset of the data for training
num_data = 15000 # can change between 500 and 1152382
train_df = df.iloc[:num_data].copy() # Use .iloc to avoid a SettingWithCopyWarning


print('Data type of each column of Dataframe :')
train_df.info(verbose=True)
# Out:
# Data type of each column of Dataframe :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 87 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          15000 non-null  int64
#  1   Src_Port                    15000 non-null  int64
#  2   Dst_Port                    15000 non-null  int64
#  3   Protocol                    15000 non-null  int64
#  4   Flow_Duration               15000 non-null  int64
#  5   Total_Fwd_Packet            15000 non-null  int64
#  6   Total_Bwd_packets           15000 non-null  int64
#  7   Total_Length_of_Fwd_Packet  15000 non-null  int64
#  8   Total_Length_of_Bwd_Packet  15000 non-null  int64
#  9   Fwd_Packet_Length_Max       15000 non-null  int64
#  10  Fwd_Packet_Length_Min       15000 non-null  int64
#  11  Fwd_Packet_Length_Mean      15000 non-null  float64
#  12  Fwd_Packet_Length_Std       15000 non-null  float64
#  13  Bwd_Packet_Length_Max       15000 non-null  int64
#  14  Bwd_Packet_Length_Min       15000 non-null  int64
#  15  Bwd_Packet_Length_Mean      15000 non-null  float64
#  16  Bwd_Packet_Length_Std       15000 non-null  float64
#  17  Flow_Bytes/s                15000 non-null  float64
#  18  Flow_Packets/s              15000 non-null  float64
#  19  Flow_IAT_Mean               15000 non-null  float64
#  20  Flow_IAT_Std                15000 non-null  float64
#  21  Flow_IAT_Max                15000 non-null  int64
#  22  Flow_IAT_Min                15000 non-null  int64
#  23  Fwd_IAT_Total               15000 non-null  int64
#  24  Fwd_IAT_Mean                15000 non-null  float64
#  25  Fwd_IAT_Std                 15000 non-null  float64
#  26  Fwd_IAT_Max                 15000 non-null  int64
#  27  Fwd_IAT_Min                 15000 non-null  int64
#  28  Bwd_IAT_Total               15000 non-null  int64
#  29  Bwd_IAT_Mean                15000 non-null  float64
#  30  Bwd_IAT_Std                 15000 non-null  float64
#  31  Bwd_IAT_Max                 15000 non-null  int64
#  32  Bwd_IAT_Min                 15000 non-null  int64
#  33  Fwd_PSH_Flags               15000 non-null  int64
#  34  Bwd_PSH_Flags               15000 non-null  int64
#  35  Fwd_URG_Flags               15000 non-null  int64
#  36  Bwd_URG_Flags               15000 non-null  int64
#  37  Fwd_RST_Flags               15000 non-null  int64
#  38  Bwd_RST_Flags               15000 non-null  int64
#  39  Fwd_Header_Length           15000 non-null  int64
#  40  Bwd_Header_Length           15000 non-null  int64
#  41  Fwd_Packets/s               15000 non-null  float64
#  42  Bwd_Packets/s               15000 non-null  float64
#  43  Packet_Length_Min           15000 non-null  int64
#  44  Packet_Length_Max           15000 non-null  int64
#  45  Packet_Length_Mean          15000 non-null  float64
#  46  Packet_Length_Std           15000 non-null  float64
#  47  Packet_Length_Variance      15000 non-null  float64
#  48  FIN_Flag_Count              15000 non-null  int64
#  49  SYN_Flag_Count              15000 non-null  int64
#  50  RST_Flag_Count              15000 non-null  int64
#  51  PSH_Flag_Count              15000 non-null  int64
#  52  ACK_Flag_Count              15000 non-null  int64
#  53  URG_Flag_Count              15000 non-null  int64
#  54  CWR_Flag_Count              15000 non-null  int64
#  55  ECE_Flag_Count              15000 non-null  int64
#  56  Down/Up_Ratio               15000 non-null  float64
#  57  Average_Packet_Size         15000 non-null  float64
#  58  Fwd_Segment_Size_Avg        15000 non-null  float64
#  59  Bwd_Segment_Size_Avg        15000 non-null  float64
#  60  Fwd_Bytes/Bulk_Avg          15000 non-null  int64
#  61  Fwd_Packet/Bulk_Avg         15000 non-null  int64
#  62  Fwd_Bulk_Rate_Avg           15000 non-null  int64
#  63  Bwd_Bytes/Bulk_Avg          15000 non-null  int64
#  64  Bwd_Packet/Bulk_Avg         15000 non-null  int64
#  65  Bwd_Bulk_Rate_Avg           15000 non-null  int64
#  66  Subflow_Fwd_Packets         15000 non-null  int64
#  67  Subflow_Fwd_Bytes           15000 non-null  int64
#  68  Subflow_Bwd_Packets         15000 non-null  int64
#  69  Subflow_Bwd_Bytes           15000 non-null  int64
#  70  FWD_Init_Win_Bytes          15000 non-null  int64
#  71  Bwd_Init_Win_Bytes          15000 non-null  int64
#  72  Fwd_Act_Data_Pkts           15000 non-null  int64
#  73  Fwd_Seg_Size_Min            15000 non-null  int64
#  74  Active_Mean                 15000 non-null  float64
#  75  Active_Std                  15000 non-null  float64
#  76  Active_Max                  15000 non-null  int64
#  77  Active_Min                  15000 non-null  int64
#  78  Idle_Mean                   15000 non-null  float64
#  79  Idle_Std                    15000 non-null  float64
#  80  Idle_Max                    15000 non-null  int64
#  81  Idle_Min                    15000 non-null  int64
#  82  ICMP_Code                   15000 non-null  int64
#  83  ICMP_Type                   15000 non-null  int64
#  84  Total_TCP_Flow_Time         15000 non-null  int64
#  85  Label                       15000 non-null  object
#  86  Attempted_Category          15000 non-null  int64
# dtypes: float64(25), int64(61), object(1)
# memory usage: 10.0+ MB

# %%
train_size = int(0.7 * len(train_df))
val_size = int(0.15 * len(train_df))
test_size = len(train_df) - train_size - val_size
train_data = train_df.iloc[:train_size, :]
val_data = train_df.iloc[train_size:train_size+val_size, :]
test_data = train_df.iloc[train_size+val_size:, :]

# %%
# Define sequence length and overlap
seq_length = 10 # Sequence length
seq_overlap = 5 # Overlap between sequences

# Function to generate sequences
def generate_sequences(data):
    seqs = []
    for i in range(0, len(data) - seq_length + 1, seq_overlap):
        seqs.append(data.iloc[i:i+seq_length, :])
    return seqs

# Generate sequences for train, validation, and test sets
train_seqs = generate_sequences(train_data)
val_seqs = generate_sequences(val_data)
test_seqs = generate_sequences(test_data)

# %%
# Function to pad sequences
def pad_sequences(seqs):
    padded_seqs = []
    for seq in seqs:
        if len(seq) < seq_length:
            padded_seq = np.concatenate((seq, np.zeros((seq_length-len(seq), len(df.columns)))), axis=0)
        else:
            padded_seq = seq
        padded_seqs.append(padded_seq)
    return np.array(padded_seqs)

# Pad sequences for train, validation, and test sets
train_seqs = pad_sequences(train_seqs)
val_seqs = pad_sequences(val_seqs)
test_seqs = pad_sequences(test_seqs)

# %%
# Reshape input
train_X = np.reshape(train_seqs, (train_seqs.shape[0], train_seqs.shape[1], len(train_df.columns)))
val_X = np.reshape(val_seqs, (val_seqs.shape[0], val_seqs.shape[1], len(train_df.columns)))
test_X = np.reshape(test_seqs, (test_seqs.shape[0], test_seqs.shape[1], len(train_df.columns)))

# %%
# Normalize data
train_X = (train_X - train_X.mean()) / train_X.std()
val_X = (val_X - train_X.mean()) / train_X.std()
test_X = (test_X - train_X.mean()) / train_X.std()

# %%
# Convert labels to categorical
train_y = to_categorical(train_data["Label"].values[:train_X.shape[0]])
val_y = to_categorical(val_data["Label"].values[:val_X.shape[0]])
test_y = to_categorical(test_data["Label"].values[:test_X.shape[0]])
train_X = train_X.astype('float32')
train_y = train_y.astype('float32')
val_X = val_X.astype('float32')
val_y = val_y.astype('float32')
test_X = test_X.astype('float32') # Added this line to convert test_X to float32

# %% [markdown]
# **For CNN-LSTM model**

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

EPOCHS = 100
BATCH_SIZE = 16
VALIDATION_SPLIT = 0.1

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True
)

optimizer = Adam(learning_rate=0.001)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.layers import LSTM, Dense, Dropout

model_cnnlstm = Sequential()

# CNN block
model_cnnlstm.add(
    Conv1D(
        filters=64,
        kernel_size=3,
        padding="same",
        activation="relu",
        input_shape=(train_X.shape[1], train_X.shape[2])
    )
)
model_cnnlstm.add(MaxPooling1D(pool_size=2))
model_cnnlstm.add(Dropout(0.3))

# LSTM block
model_cnnlstm.add(
    LSTM(
        units=64,
        return_sequences=False
    )
)
model_cnnlstm.add(Dropout(0.3))

# Output layer
model_cnnlstm.add(Dense(2, activation='softmax'))

model_cnnlstm.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model_cnnlstm.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_21 (Conv1D)              │ (None, 10, 64)         │        16,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_11 (MaxPooling1D) │ (None, 5, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 5, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,922 (195.01 KB)
#  Trainable params: 49,922 (195.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_cnnlstm = model_cnnlstm.fit(
    train_X, train_y,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=VALIDATION_SPLIT,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.4774 - loss: 0.7131 - val_accuracy: 0.4619 - val_loss: 0.7004
# Epoch 2/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4826 - loss: 0.7075 - val_accuracy: 0.5524 - val_loss: 0.6944
# Epoch 3/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5137 - loss: 0.6968 - val_accuracy: 0.5333 - val_loss: 0.6916
# Epoch 4/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5270 - loss: 0.6945 - val_accuracy: 0.4667 - val_loss: 0.7008
# Epoch 5/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5293 - loss: 0.6930 - val_accuracy: 0.5667 - val_loss: 0.6918
# Epoch 6/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5183 - loss: 0.6942 - val_accuracy: 0.5286 - val_loss: 0.6890
# Epoch 7/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5256 - loss: 0.6896 - val_accuracy: 0.5000 - val_loss: 0.7133
# Epoch 8/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5444 - loss: 0.6815 - val_accuracy: 0.5381 - val_loss: 0.6847
# Epoch 9/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5379 - loss: 0.6919 - val_accuracy: 0.5238 - val_loss: 0.6954
# Epoch 10/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5537 - loss: 0.6873 - val_accuracy: 0.5524 - val_loss: 0.6854
# Epoch 11/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5635 - loss: 0.6817 - val_accuracy: 0.5190 - val_loss: 0.6880
# Epoch 12/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5992 - loss: 0.6747 - val_accuracy: 0.5476 - val_loss: 0.6944
# Epoch 13/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5806 - loss: 0.6755 - val_accuracy: 0.5000 - val_loss: 0.7058
# Epoch 14/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5678 - loss: 0.6784 - val_accuracy: 0.5286 - val_loss: 0.6877
# Epoch 15/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5674 - loss: 0.6779 - val_accuracy: 0.5286 - val_loss: 0.6982
# Epoch 16/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5837 - loss: 0.6709 - val_accuracy: 0.5238 - val_loss: 0.6960
# Epoch 17/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5689 - loss: 0.6751 - val_accuracy: 0.5333 - val_loss: 0.6946
# Epoch 18/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5647 - loss: 0.6757 - val_accuracy: 0.5571 - val_loss: 0.7022
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %%
#loss plot
plt.plot(history.history['loss'])
plt.plot(history.history['loss'], 'o')
plt.plot(history.history['val_loss'], 'o')
plt.plot(history.history['val_loss'])
plt.title('comparing predict and real value loss presentage')
plt.xlabel('Loss persentage')
plt.ylabel('Epoch')
plt.legend(['Predict_loss','Predict_loss points','Real_loss points', 'Real_loss'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#accuracy plot
plt.plot(history.history['accuracy'])
plt.plot(history.history['accuracy'],'o')
plt.plot(history.history['val_accuracy'])
plt.plot(history.history['val_accuracy'],'o')
plt.title('comparing predict and real accuracy presentage')
plt.xlabel('Accuracy persentage')
plt.ylabel('Epoch')
plt.legend(['Predict_Accuracy','Predict_Accuracy points', 'Real_accuracy','Real_accuracy points'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
# Predict on training data
y_pred_prob = model.predict(train_X)

# Convert probabilities to binary labels
y_pred = (y_pred_prob > 0.5).astype(int).reshape(-1)
y_true = train_y.reshape(-1)
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy  = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall    = recall_score(y_true, y_pred)   # Detection Rate
f1        = f1_score(y_true, y_pred)

print(" MODEL EVALUATION METRICS")
print(f"Accuracy        : {accuracy:.4f}")
print(f"Precision       : {precision:.4f}")
print(f"Recall (DR)     : {recall:.4f}")
print(f"F1-score        : {f1:.4f}")
# Out:
#  MODEL EVALUATION METRICS
# Accuracy        : 0.5622
# Precision       : 0.5622
# Recall (DR)     : 0.5622
# F1-score        : 0.5622

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred)
TN, FP, FN, TP = cm.ravel()

print("\n CONFUSION MATRIX")
print(cm)

print("\n ERROR ANALYSIS")
print(f"True Positives  (TP): {TP}")
print(f"True Negatives  (TN): {TN}")
print(f"False Positives (FP): {FP}")
print(f"False Negatives (FN): {FN}")

false_positive_rate = FP / (FP + TN)
false_negative_rate = FN / (FN + TP)

print(f"False Positive Rate : {false_positive_rate:.4f}")
print(f"False Negative Rate : {false_negative_rate:.4f}")
# Out:
#  CONFUSION MATRIX
# [[1180  919]
#  [ 919 1180]]
#
#  ERROR ANALYSIS
# True Positives  (TP): 1180
# True Negatives  (TN): 1180
# False Positives (FP): 919
# False Negatives (FN): 919
# False Positive Rate : 0.4378
# False Negative Rate : 0.4378

# %%
from sklearn.metrics import classification_report

print("\n CLASSIFICATION REPORT")
print(classification_report(
    y_true,
    y_pred,
    target_names=['BENIGN', 'ATTACK'],
    digits=4
))
# Out:
#  CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#       BENIGN     0.5622    0.5622    0.5622      2099
#       ATTACK     0.5622    0.5622    0.5622      2099
#
#     accuracy                         0.5622      4198
#    macro avg     0.5622    0.5622    0.5622      4198
# weighted avg     0.5622    0.5622    0.5622      4198

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=['BENIGN', 'ATTACK'],
    yticklabels=['BENIGN', 'ATTACK']
)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
